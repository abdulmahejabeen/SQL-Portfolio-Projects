# %% [markdown]
# ## 1. The ten best-selling video games
# <p><img src="https://assets.datacamp.com/production/project_1413/img/video_game.jpg" alt="A video game player choosing a game to play on Nintendo Switch." width="400"></p>
# <p>Photo by <a href="https://unsplash.com/@retromoon">Dan Schleusser</a> on <a href="https://unsplash.com">Unsplash</a>.</p>
# <p>Video games are big business: the global gaming market is projected to be worth more than $300 billion by 2027 according to <a href="https://www.mordorintelligence.com/industry-reports/global-gaming-market">Mordor Intelligence</a>. With so much money at stake, the major game publishers are hugely incentivized to create the next big hit. But are games getting better, or has the golden age of video games already passed?</p>
# <p>In this project, we'll explore the top 400 best-selling video games created between 1977 and 2020. We'll compare a dataset on game sales with critic and user reviews to determine whether or not video games have improved as the gaming market has grown.</p>
# <p>Our database contains two tables. We've limited each table to 400 rows for this project, but you can find the complete dataset with over 13,000 games on <a href="https://www.kaggle.com/holmjason2/videogamedata">Kaggle</a>. </p>
# <h3 id="game_sales"><code>game_sales</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>game</code></td>
# <td>varchar</td>
# <td>Name of the video game</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>platform</code></td>
# <td>varchar</td>
# <td>Gaming platform</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>publisher</code></td>
# <td>varchar</td>
# <td>Game publisher</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>developer</code></td>
# <td>varchar</td>
# <td>Game developer</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>games_sold</code></td>
# <td>float</td>
# <td>Number of copies sold (millions)</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>year</code></td>
# <td>int</td>
# <td>Release year</td>
# </tr>
# </tbody>
# </table>
# <h3 id="reviews"><code>reviews</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>game</code></td>
# <td>varchar</td>
# <td>Name of the video game</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>critic_score</code></td>
# <td>float</td>
# <td>Critic score according to Metacritic</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>user_score</code></td>
# <td>float</td>
# <td>User score according to Metacritic</td>
# </tr>
# </tbody>
# </table>
# <p>Let's begin by looking at some of the top selling video games of all time!</p>

# %%
# %%sql
# postgresql:///games
#
# select * from game_sales
# Out:
# 400 rows affected.
# [('7 Days to Die for PC', 'PC', 'The Fun Pimps', 'The Fun Pimps', Decimal('4.18'), 2013),
#  ('ARK: Survival Evolved for PC', 'PC', 'Studio Wildcard', 'Studio Wildcard', Decimal('4.50'), 2015),
#  ('Age of Empires II: HD Edition for PC', 'PC', 'Microsoft Studios', 'Hidden Path Entertainment', Decimal('5.82'), 2013),
#  ('Animal Crossing: City Folk for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('4.32'), 2008),
#  ('Animal Crossing: New Horizons for NS', 'NS', 'Nintendo', 'Nintendo', Decimal('13.41'), 2020),
#  ('Animal Crossing: New Leaf for 3DS', '3DS', 'Nintendo', 'Nintendo EAD', Decimal('12.55'), 2013),
#  ('Animal Crossing: Wild World for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('11.75'), 2005),
#  ('Arma 2: Operation Arrowhead for PC', 'PC', 'Meridian4', 'Bohemia Interactive', Decimal('4.51'), 2010),
#  ('Arma III for PC', 'PC', 'Bohemia Interactive', 'Bohemia Interactive', Decimal('4.00'), 2013),
#  ("Assassin's Creed II for PS3", 'PS3', 'Ubisoft', 'Ubisoft Montreal', Decimal('5.57'), 2009),
#  ("Assassin's Creed II for X360", 'X360', 'Ubisoft', 'Ubisoft Montreal', Decimal('5.30'), 2009),
#  ("Assassin's Creed III for PS3", 'PS3', 'Ubisoft', 'Ubisoft Montreal', Decimal('6.50'), 2012),
#  ("Assassin's Creed III for X360", 'X360', 'Ubisoft', 'Ubisoft Montreal', Decimal('5.31'), 2012),
#  ("Assassin's Creed Origins for PS4", 'PS4', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.06'), 2017),
#  ("Assassin's Creed for PS3", 'PS3', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.83'), 2007),
#  ("Assassin's Creed for X360", 'X360', 'Ubisoft', 'Ubisoft Montreal', Decimal('5.55'), 2007),
#  ("Assassin's Creed: Revelations for PS3", 'PS3', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.23'), 2011),
#  ("Assassin's Creed: Revelations for X360", 'X360', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.22'), 2011),
#  ("Assassin's Creed: Unity for PS4", 'PS4', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.14'), 2014),
#  ('Asteroids for 2600', '2600', 'Atari', 'Atari', Decimal('4.31'), 1981),
#  ('Batman: Arkham Asylum for PS3', 'PS3', 'Eidos Interactive', 'Rocksteady Studios', Decimal('4.28'), 2009),
#  ('Batman: Arkham City for PS3', 'PS3', 'Warner Bros. Interactive', 'Rocksteady Studios', Decimal('5.54'), 2011),
#  ('Batman: Arkham City for X360', 'X360', 'Warner Bros. Interactive', 'Rocksteady Studios', Decimal('4.75'), 2011),
#  ('Batman: Arkham Knight for PS4', 'PS4', 'Warner Bros. Interactive', 'Rocksteady Studios', Decimal('4.11'), 2015),
#  ('Battlefield 1 for PS4', 'PS4', 'Electronic Arts', 'EA DICE', Decimal('7.26'), 2016),
#  ('Battlefield 1 for XOne', 'XOne', 'Electronic Arts', 'EA DICE', Decimal('5.13'), 2016),
#  ('Battlefield 3 for PS3', 'PS3', 'Electronic Arts', 'Dice', Decimal('7.21'), 2011),
#  ('Battlefield 3 for X360', 'X360', 'Electronic Arts', 'Dice', Decimal('7.35'), 2011),
#  ('Big Brain Academy for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('6.15'), 2006),
#  ('BioShock Infinite for PC', 'PC', '2K Games', 'Irrational Games', Decimal('4.56'), 2013),
#  ('Brain Age 2: More Training in Minutes a Day for DS', 'DS', 'Nintendo', 'Nintendo SDD', Decimal('14.88'), 2007),
#  ('Brain Age: Train Your Brain in Minutes a Day for DS', 'DS', 'Nintendo', 'Nintendo SDD', Decimal('19.01'), 2006),
#  ('Call of Duty 4: Modern Warfare for PS3', 'PS3', 'Activision', 'Infinity Ward', Decimal('6.72'), 2007),
#  ('Call of Duty 4: Modern Warfare for X360', 'X360', 'Activision', 'Infinity Ward', Decimal('9.41'), 2007),
#  ('Call of Duty: Advanced Warfare for PS3', 'PS3', 'Activision', 'High Moon Studios', Decimal('4.27'), 2014),
#  ('Call of Duty: Advanced Warfare for PS4', 'PS4', 'Activision', 'Sledgehammer Games', Decimal('7.53'), 2014),
#  ('Call of Duty: Advanced Warfare for X360', 'X360', 'Activision', 'High Moon Studios', Decimal('4.34'), 2014),
#  ('Call of Duty: Advanced Warfare for XOne', 'XOne', 'Activision', 'Sledgehammer Games', Decimal('5.22'), 2014),
#  ('Call of Duty: Black Ops 3 for PS4', 'PS4', 'Activision', 'Treyarch', Decimal('15.09'), 2015),
#  ('Call of Duty: Black Ops 3 for XOne', 'XOne', 'Activision', 'Treyarch', Decimal('7.37'), 2015),
#  ('Call of Duty: Black Ops II for PS3', 'PS3', 'Activision', 'Treyarch', Decimal('13.80'), 2012),
#  ('Call of Duty: Black Ops II for X360', 'X360', 'Activision', 'Treyarch', Decimal('13.86'), 2012),
#  ('Call of Duty: Black Ops IIII for PS4', 'PS4', 'Activision', 'Treyarch', Decimal('9.32'), 2018),
#  ('Call of Duty: Black Ops IIII for XOne', 'XOne', 'Activision', 'Treyarch', Decimal('4.85'), 2018),
#  ('Call of Duty: Black Ops for PS3', 'PS3', 'Activision', 'Treyarch', Decimal('12.67'), 2010),
#  ('Call of Duty: Black Ops for X360', 'X360', 'Activision', 'Treyarch', Decimal('14.74'), 2010),
#  ('Call of Duty: Ghosts for PS3', 'PS3', 'Activision', 'Infinity Ward', Decimal('10.13'), 2013),
#  ('Call of Duty: Ghosts for PS4', 'PS4', 'Activision', 'Infinity Ward', Decimal('4.17'), 2013),
#  ('Call of Duty: Ghosts for X360', 'X360', 'Activision', 'Infinity Ward', Decimal('10.41'), 2013),
#  ('Call of Duty: Infinite Warfare for PS4', 'PS4', 'Activision', 'Infinity Ward', Decimal('8.48'), 2016),
#  ('Call of Duty: Infinite Warfare for XOne', 'XOne', 'Activision', 'Infinity Ward', Decimal('4.79'), 2016),
#  ('Call of Duty: Modern Warfare 2 for PS3', 'PS3', 'Activision', 'Infinity Ward', Decimal('10.61'), 2009),
#  ('Call of Duty: Modern Warfare 2 for X360', 'X360', 'Activision', 'Infinity Ward', Decimal('13.53'), 2009),
#  ('Call of Duty: Modern Warfare 3 for PS3', 'PS3', 'Activision', 'Infinity Ward', Decimal('13.35'), 2011),
#  ('Call of Duty: Modern Warfare 3 for X360', 'X360', 'Activision', 'Infinity Ward', Decimal('14.82'), 2011),
#  ('Call of Duty: Modern Warfare for PS4', 'PS4', 'Activision', 'Infinity Ward', Decimal('30.13'), 2019),
#  ('Call of Duty: WWII for PS4', 'PS4', 'Activision', 'Sledgehammer Games', Decimal('13.40'), 2017),
#  ('Call of Duty: WWII for XOne', 'XOne', 'Activision', 'Sledgehammer Games', Decimal('6.23'), 2017),
#  ('Call of Duty: World at War for PS3', 'PS3', 'Activision', 'Treyarch', Decimal('5.43'), 2008),
#  ('Call of Duty: World at War for X360', 'X360', 'Activision', 'Treyarch', Decimal('7.50'), 2008),
#  ('Carnival Games for Wii', 'Wii', 'Global Star Software', 'Cat Daddy Games', Decimal('4.06'), 2007),
#  ('Cities: Skylines for PC', 'PC', 'Paradox Interactive', 'Colossal Order', Decimal('6.00'), 2015),
#  ('Cooking Mama for DS', 'DS', 'Majesco', 'Office Create', Decimal('5.66'), 2006),
#  ('Counter-Strike for PC', 'PC', 'Sierra Studios', 'Unknown', Decimal('4.20'), 2000),
#  ('Counter-Strike: Global Offensive for PC', 'PC', 'Valve', 'Valve Corporation', Decimal('40.00'), 2012),
#  ('Counter-Strike: Source for PC', 'PC', 'VU Games', 'Valve Software', Decimal('15.00'), 2004),
#  ('Crash Bandicoot 2: Cortex Strikes Back for PS', 'PS', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('7.58'), 1997),
#  ('Crash Bandicoot 3: Warped for PS', 'PS', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('7.13'), 1998),
#  ('Crash Bandicoot N. Sane Trilogy for PS4', 'PS4', 'Activision', 'Vicarious Visions', Decimal('4.83'), 2017),
#  ('Crash Bandicoot for PS', 'PS', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('6.82'), 1996),
#  ('Crash Bandicoot: The Wrath of Cortex for PS2', 'PS2', 'Universal Interactive', "Traveller's Tales", Decimal('5.42'), 2001),
#  ('Crash Team Racing for PS', 'PS', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('4.79'), 1999),
#  ('Daxter for PSP', 'PSP', 'Sony Computer Entertainment', 'Ready at Dawn', Decimal('4.23'), 2006),
#  ('Dead Island for PC', 'PC', 'Deep Silver', 'Techland', Decimal('4.52'), 2011),
#  ('Destiny 2 for PS4', 'PS4', 'Activision', 'Bungie', Decimal('4.14'), 2017),
#  ('Destiny for PS4', 'PS4', 'Activision', 'Bungie', Decimal('5.76'), 2014),
#  ('Diablo II for PC', 'PC', 'Blizzard Entertainment', 'Blizzard North', Decimal('4.00'), 2000),
#  ('Diablo III for PC', 'PC', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('12.00'), 2012),
#  ('Diddy Kong Racing for N64', 'N64', 'Nintendo', 'Rare Ltd.', Decimal('4.88'), 1997),
#  ("Disney's Aladdin for GEN", 'GEN', 'Sega', 'Virgin Interactive', Decimal('4.00'), 1993),
#  ('Donkey Kong 64 for N64', 'N64', 'Nintendo', 'Rare Ltd.', Decimal('5.27'), 1999),
#  ("Donkey Kong Country 2: Diddy's Kong Quest for SNES", 'SNES', 'Nintendo', 'Rare Ltd.', Decimal('5.15'), 1995),
#  ('Donkey Kong Country Returns for Wii', 'Wii', 'Nintendo', 'Retro Studios', Decimal('6.53'), 2010),
#  ('Donkey Kong Country for SNES', 'SNES', 'Nintendo', 'Rare Ltd.', Decimal('9.30'), 1994),
#  ('Dr. Mario for GB', 'GB', 'Nintendo', 'Nintendo R&D1', Decimal('5.34'), 1990),
#  ('Dr. Mario for NES', 'NES', 'Nintendo', 'Nintendo R&D1', Decimal('4.85'), 1990),
#  ('Dragon Quest IX: Sentinels of the Starry Skies for DS', 'DS', 'Nintendo', 'Level 5', Decimal('5.50'), 2010),
#  ('Dragon Quest VII for PS', 'PS', 'Enix', 'Heart Beat', Decimal('4.30'), 2001),
#  ('Dragon Quest VIII: Journey of the Cursed King for PS2', 'PS2', 'Square Enix', 'Level 5 / Armor Project', Decimal('4.90'), 2005),
#  ('Driver 2 for PS', 'PS', 'Atari', 'Reflections Interactive', Decimal('4.73'), 2000),
#  ('Driver for PS', 'PS', 'GT Interactive', 'Reflections Interactive', Decimal('6.27'), 1999),
#  ('Duck Hunt for NES', 'NES', 'Nintendo', 'Nintendo R&D1', Decimal('28.31'), 1985),
#  ('Euro Truck Simulator 2 for PC', 'PC', 'SCS Software', 'SCS Software', Decimal('5.98'), 2013),
#  ('Excitebike for NES', 'NES', 'Nintendo', 'Nintendo R&D1', Decimal('4.16'), 1985),
#  ('EyeToy Play for PS2', 'PS2', 'Sony Computer Entertainment', 'SCEE London Studio', Decimal('4.00'), 2003),
#  ('FIFA 07 Soccer for PS2', 'PS2', 'EA Sports', 'Team Fusion', Decimal('4.11'), 2006),
#  ('FIFA 13 for PS3', 'PS3', 'EA Sports', 'EA Canada', Decimal('8.01'), 2012),
#  ('FIFA 13 for X360', 'X360', 'EA Sports', 'EA Canada', Decimal('5.11'), 2012),
#  ('FIFA 14 for PS3', 'PS3', 'EA Sports', 'EA Canada', Decimal('6.61'), 2013),
#  ('FIFA 14 for X360', 'X360', 'EA Sports', 'EA Canada', Decimal('4.15'), 2013),
#  ('FIFA 15 for PS3', 'PS3', 'EA Sports', 'EA Canada', Decimal('4.56'), 2014),
#  ('FIFA 15 for PS4', 'PS4', 'EA Sports', 'EA Canada', Decimal('6.32'), 2014),
#  ('FIFA 16 for PS4', 'PS4', 'EA Sports', 'EA Canada', Decimal('8.22'), 2015),
#  ('FIFA 17 for PS4', 'PS4', 'Electronic Arts', 'EA Canada', Decimal('10.94'), 2016),
#  ('FIFA 18 for PS4', 'PS4', 'EA Sports', 'EA Vancouver', Decimal('11.80'), 2017),
#  ('FIFA 19 for PS4', 'PS4', 'Electronic Arts', 'EA Sports', Decimal('9.15'), 2018),
#  ('FIFA 20 for PS4', 'PS4', 'Electronic Arts', 'EA Sports', Decimal('7.15'), 2019),
#  ('FIFA Soccer 06 for PS2', 'PS2', 'EA Sports', 'EA Canada', Decimal('4.21'), 2005),
#  ('FIFA Soccer 11 for PS3', 'PS3', 'EA Sports', 'EA Canada', Decimal('5.08'), 2010),
#  ('FIFA Soccer 12 for PS3', 'PS3', 'EA Sports', 'EA Canada', Decimal('6.65'), 2011),
#  ('FIFA Soccer 12 for X360', 'X360', 'EA Sports', 'EA Canada', Decimal('4.18'), 2011),
#  ('Fable III for X360', 'X360', 'Microsoft Game Studios', 'Lionhead Studios', Decimal('5.10'), 2010),
#  ('Fallout 3 for PS3', 'PS3', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('4.00'), 2008),
#  ('Fallout 3 for X360', 'X360', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('4.96'), 2008),
#  ('Fallout 4 for PC', 'PC', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('6.60'), 2015),
#  ('Fallout 4 for PS4', 'PS4', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('8.48'), 2015),
#  ('Fallout 4 for XOne', 'XOne', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('5.03'), 2015),
#  ('Fallout: New Vegas for PC', 'PC', 'Bethesda Softworks', 'Obsidian Entertainment', Decimal('5.22'), 2010),
#  ('Fallout: New Vegas for X360', 'X360', 'Bethesda Softworks', 'Obsidian Entertainment', Decimal('4.08'), 2010),
#  ('Far Cry 4 for PS4', 'PS4', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.06'), 2014),
#  ('Final Fantasy IX for PS', 'PS', 'Square', 'SquareSoft', Decimal('5.50'), 2000),
#  ('Final Fantasy VII for PS', 'PS', 'Sony Computer Entertainment', 'SquareSoft', Decimal('9.90'), 1997),
#  ('Final Fantasy VIII for PS', 'PS', 'Square EA', 'SquareSoft', Decimal('8.60'), 1999),
#  ('Final Fantasy X for PS2', 'PS2', 'Square', 'SquareSoft', Decimal('8.60'), 2001),
#  ('Final Fantasy X-2 for PS2', 'PS2', 'Square Enix', 'Square Enix', Decimal('5.50'), 2003),
#  ('Final Fantasy XII for PS2', 'PS2', 'Square Enix', 'Square Enix', Decimal('6.40'), 2006),
#  ('Final Fantasy XIII for PS3', 'PS3', 'Square Enix', 'Square Enix', Decimal('5.35'), 2010),
#  ('Final Fantasy XV for PS4', 'PS4', 'Square Enix', 'Square Enix', Decimal('5.07'), 2016),
#  ('Forza Motorsport 2 for X360', 'X360', 'Microsoft Game Studios', 'Turn 10 Studios', Decimal('4.05'), 2007),
#  ('Forza Motorsport 3 for X360', 'X360', 'Microsoft Game Studios', 'Turn 10 Studios', Decimal('5.50'), 2009),
#  ('Forza Motorsport 4 for X360', 'X360', 'Microsoft Studios', 'Turn 10 Studio', Decimal('4.60'), 2011),
#  ('Frogger for PS', 'PS', 'Hasbro Interactive', 'Millenium Interactive', Decimal('4.16'), 1997),
#  ("Garry's Mod for PC", 'PC', 'Valve', 'Facepunch Studios', Decimal('16.90'), 2006),
#  ('Gears of War 2 for X360', 'X360', 'Microsoft Game Studios', 'Epic Games', Decimal('5.00'), 2008),
#  ('Gears of War for X360', 'X360', 'Microsoft Game Studios', 'Epic Games', Decimal('5.00'), 2006),
#  ('God of War (2018) for PS4', 'PS4', 'Sony Interactive Entertainment', 'SIE Santa Monica Studio', Decimal('11.00'), 2018),
#  ('God of War II for PS2', 'PS2', 'Sony Computer Entertainment', 'SCEA Santa Monica Studio', Decimal('4.24'), 2007),
#  ('God of War III for PS3', 'PS3', 'Sony Computer Entertainment', 'SCEA Santa Monica Studio', Decimal('7.60'), 2010),
#  ('God of War for PS2', 'PS2', 'Sony Computer Entertainment', 'SCEA Santa Monica Studio', Decimal('4.62'), 2005),
#  ('GoldenEye 007 for N64', 'N64', 'Nintendo', 'Rare Ltd.', Decimal('8.09'), 1997),
#  ('Golf for NES', 'NES', 'Nintendo', 'Nintendo', Decimal('4.01'), 1985),
#  ('Gran Turismo 2 for PS', 'PS', 'Sony Computer Entertainment', 'Polyphony Digital', Decimal('9.37'), 1999),
#  ('Gran Turismo 3: A-Spec for PS2', 'PS2', 'Sony Computer Entertainment', 'Polyphony Digital', Decimal('14.89'), 2001),
#  ('Gran Turismo 4 for PS2', 'PS2', 'Sony Computer Entertainment', 'Polyphony Digital', Decimal('11.76'), 2005),
#  ('Gran Turismo 5 Prologue for PS3', 'PS3', 'Sony Computer Entertainment', 'Polyphony Digital', Decimal('5.35'), 2008),
#  ('Gran Turismo 5 for PS3', 'PS3', 'Sony Computer Entertainment', 'Polyphony Digital', Decimal('11.95'), 2010),
#  ('Gran Turismo 6 for PS3', 'PS3', 'Sony Computer Entertainment America', 'Polyphony Digital', Decimal('5.22'), 2013),
#  ('Gran Turismo for PS', 'PS', 'Sony Computer Entertainment', 'Polyphony Digital', Decimal('10.85'), 1998),
#  ('Gran Turismo for PSP', 'PSP', 'Sony Computer Entertainment', 'Polyphony Digital', Decimal('4.67'), 2009),
#  ('Grand Theft Auto III for PS2', 'PS2', 'Rockstar Games', 'DMA Design', Decimal('13.10'), 2001),
#  ('Grand Theft Auto IV for PS3', 'PS3', 'Rockstar Games', 'Rockstar North', Decimal('10.57'), 2008),
#  ('Grand Theft Auto IV for X360', 'X360', 'Rockstar Games', 'Rockstar North', Decimal('11.09'), 2008),
#  ('Grand Theft Auto V for PC', 'PC', 'Rockstar Games', 'Rockstar North', Decimal('12.60'), 2015),
#  ('Grand Theft Auto V for PS3', 'PS3', 'Rockstar Games', 'Rockstar North', Decimal('20.32'), 2013),
#  ('Grand Theft Auto V for PS4', 'PS4', 'Rockstar Games', 'Rockstar North', Decimal('19.39'), 2014),
#  ('Grand Theft Auto V for X360', 'X360', 'Rockstar Games', 'Rockstar North', Decimal('15.86'), 2013),
#  ('Grand Theft Auto V for XOne', 'XOne', 'Rockstar Games', 'Rockstar North', Decimal('8.72'), 2014),
#  ('Grand Theft Auto: Liberty City Stories for PSP', 'PSP', 'Rockstar Games', 'Rockstar Leeds', Decimal('7.72'), 2005),
#  ('Grand Theft Auto: San Andreas for PS2', 'PS2', 'Rockstar Games', 'Rockstar North', Decimal('17.30'), 2004),
#  ('Grand Theft Auto: Vice City Stories for PSP', 'PSP', 'Rockstar Games', 'Rockstar Leeds', Decimal('5.08'), 2006),
#  ('Grand Theft Auto: Vice City for PS2', 'PS2', 'Rockstar Games', 'Rockstar North', Decimal('16.15'), 2002),
#  ('Guild Wars 2 for PC', 'PC', 'NCSoft', 'ArenaNet', Decimal('7.00'), 2012),
#  ('Guild Wars for PC', 'PC', 'NCSoft', 'ArenaNet', Decimal('6.50'), 2005),
#  ('Guitar Hero II for PS2', 'PS2', 'RedOctane', 'Harmonix Music Systems', Decimal('5.12'), 2006),
#  ('Guitar Hero III: Legends of Rock for PS2', 'PS2', 'RedOctane', 'BudCat Creations', Decimal('4.98'), 2007),
#  ('Guitar Hero III: Legends of Rock for Wii', 'Wii', 'RedOctane', 'Vicarious Visions', Decimal('4.60'), 2007),
#  ('Guitar Hero III: Legends of Rock for X360', 'X360', 'RedOctane', 'Neversoft', Decimal('4.53'), 2007),
#  ('Half-Life 2 for PC', 'PC', 'VU Games', 'Valve Software', Decimal('12.00'), 2004),
#  ('Half-Life for PC', 'PC', 'Sierra Entertainment', 'Valve Software', Decimal('9.30'), 1998),
#  ('Halo 2 for XB', 'XB', 'Microsoft Game Studios', 'Bungie Studios', Decimal('8.00'), 2004),
#  ('Halo 3 for X360', 'X360', 'Microsoft Game Studios', 'Bungie Studios', Decimal('14.50'), 2007),
#  ('Halo 3: ODST for X360', 'X360', 'Microsoft Game Studios', 'Bungie', Decimal('6.35'), 2009),
#  ('Halo 4 for X360', 'X360', 'Microsoft Studios', '343 Industries', Decimal('9.96'), 2012),
#  ('Halo 5: Guardians for XOne', 'XOne', 'Microsoft Studios', '343 Industries', Decimal('5.00'), 2015),
#  ('Halo: Combat Evolved for XB', 'XB', 'Microsoft', 'Bungie Studios', Decimal('5.00'), 2001),
#  ('Halo: Reach for X360', 'X360', 'Microsoft Game Studios', 'Bungie', Decimal('9.97'), 2010),
#  ('Horizon: Zero Dawn for PS4', 'PS4', 'Sony Interactive Entertainment', 'Guerrilla Games', Decimal('10.00'), 2017),
#  ('Just Cause 2 for PC', 'PC', 'Eidos Interactive', 'Avalanche Studios', Decimal('4.16'), 2010),
#  ('Just Dance 2 for Wii', 'Wii', 'Ubisoft', 'Ubisoft Paris', Decimal('5.25'), 2010),
#  ('Just Dance 3 for Wii', 'Wii', 'Ubisoft', 'Ubisoft Paris', Decimal('10.14'), 2011),
#  ('Just Dance 4 for Wii', 'Wii', 'Ubisoft', 'Ubisoft', Decimal('6.89'), 2012),
#  ('Just Dance for Wii', 'Wii', 'Ubisoft', 'Ubisoft Paris', Decimal('4.00'), 2009),
#  ('Kinect Adventures! for X360', 'X360', 'Microsoft Game Studios', 'Good Science Studio', Decimal('24.00'), 2010),
#  ('Kingdom Hearts II for PS2', 'PS2', 'Square Enix', 'Square Enix', Decimal('5.20'), 2006),
#  ('Kingdom Hearts for PS2', 'PS2', 'Square EA', 'SquareSoft', Decimal('6.30'), 2002),
#  ("Kirby's Dream Land for GB", 'GB', 'Nintendo', 'HAL Laboratory', Decimal('5.13'), 1992),
#  ('LEGO Star Wars: The Complete Saga for DS', 'DS', 'LucasArts', "Traveller's Tales", Decimal('4.77'), 2007),
#  ('LEGO Star Wars: The Complete Saga for Wii', 'Wii', 'LucasArts', "Traveller's Tales", Decimal('5.66'), 2007),
#  ('Left 4 Dead for PC', 'PC', 'Valve Corporation', 'Valve Software', Decimal('4.60'), 2008),
#  ("Link's Crossbow Training for Wii", 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('5.79'), 2007),
#  ('LittleBigPlanet for PS3', 'PS3', 'Sony Computer Entertainment', 'Media Molecule', Decimal('4.50'), 2008),
#  ("Luigi's Mansion 3 for NS", 'NS', 'Nintendo', 'Next Level Games, Inc.', Decimal('6.33'), 2019),
#  ("Luigi's Mansion: Dark Moon for 3DS", '3DS', 'Nintendo', 'Next Level Games', Decimal('6.16'), 2013),
#  ('Madden NFL 06 for PS2', 'PS2', 'EA Sports', 'EA Tiburon', Decimal('4.91'), 2005),
#  ('Madden NFL 07 for PS2', 'PS2', 'EA Sports', 'EA Tiburon', Decimal('4.49'), 2006),
#  ('Madden NFL 2003 for PS2', 'PS2', 'EA Sports', 'EA Tiburon', Decimal('4.14'), 2002),
#  ('Madden NFL 2004 for PS2', 'PS2', 'EA Sports', 'EA Tiburon', Decimal('5.23'), 2003),
#  ('Madden NFL 2005 for PS2', 'PS2', 'EA Sports', 'EA Tiburon', Decimal('4.53'), 2004),
#  ("Mario & Luigi: Bowser's Inside Story for DS", 'DS', 'Nintendo', 'AlphaDream Corporation', Decimal('4.56'), 2009),
#  ('Mario & Sonic at the Olympic Games for DS', 'DS', 'Sega', 'Sega', Decimal('5.10'), 2008),
#  ('Mario & Sonic at the Olympic Winter Games for Wii', 'Wii', 'Sega', 'Sega', Decimal('4.54'), 2009),
#  ('Mario Kart 64 for N64', 'N64', 'Nintendo', 'Nintendo EAD', Decimal('9.87'), 1997),
#  ('Mario Kart 7 for 3DS', '3DS', 'Nintendo', 'Nintendo EAD / Retro Studios', Decimal('18.71'), 2011),
#  ('Mario Kart 8 Deluxe for NS', 'NS', 'Nintendo', 'Nintendo EPD', Decimal('24.77'), 2017),
#  ('Mario Kart 8 for WiiU', 'WiiU', 'Nintendo', 'Nintendo', Decimal('8.45'), 2014),
#  ('Mario Kart DS for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('23.60'), 2005),
#  ('Mario Kart Wii for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('37.32'), 2008),
#  ('Mario Kart: Double Dash!! for GC', 'GC', 'Nintendo', 'Nintendo EAD', Decimal('6.88'), 2003),
#  ('Mario Kart: Super Circuit for GBA', 'GBA', 'Nintendo', 'Intelligent Systems', Decimal('5.91'), 2001),
#  ('Mario Party 8 for Wii', 'Wii', 'Nintendo', 'Hudson Soft', Decimal('8.85'), 2007),
#  ('Mario Party DS for DS', 'DS', 'Nintendo', 'Hudson Soft', Decimal('9.31'), 2007),
#  ("Marvel's Spider-Man for PS4", 'PS4', 'Sony Interactive Entertainment', 'Insomniac Games', Decimal('13.20'), 2018),
#  ('Medal of Honor: Frontline for PS2', 'PS2', 'Electronic Arts', 'EA Los Angeles', Decimal('6.83'), 2002),
#  ('Medal of Honor: Rising Sun for PS2', 'PS2', 'Electronic Arts', 'EA Los Angeles', Decimal('5.13'), 2003),
#  ('Metal Gear Solid 2: Sons of Liberty for PS2', 'PS2', 'Konami', 'Konami Computer Entertainment Japan', Decimal('6.05'), 2001),
#  ('Metal Gear Solid 3: Snake Eater for PS2', 'PS2', 'Konami', 'KCEJ / Kojima Productions', Decimal('4.23'), 2004),
#  ('Metal Gear Solid 4: Guns of the Patriots for PS3', 'PS3', 'Konami', 'Kojima Productions', Decimal('6.00'), 2008),
#  ('Metal Gear Solid for PS', 'PS', 'Konami', 'Konami Computer Entertainment Japan', Decimal('6.00'), 1998),
#  ('Michael Jackson: The Experience for Wii', 'Wii', 'Ubisoft', 'Ubisoft Montpellier', Decimal('4.37'), 2010),
#  ('Microsoft Flight Simulator for PC', 'PC', 'Microsoft', 'Microsoft', Decimal('5.12'), 1996),
#  ('Minecraft for PC', 'PC', 'Mojang', 'Mojang AB', Decimal('33.15'), 2010),
#  ('Minecraft for PS3', 'PS3', 'Sony Computer Entertainment America', 'Mojang', Decimal('6.05'), 2014),
#  ('Minecraft for PS4', 'PS4', 'Sony Computer Entertainment', 'Mojang', Decimal('6.33'), 2014),
#  ('Minecraft for X360', 'X360', 'Microsoft Studios', 'Mojang', Decimal('13.00'), 2013),
#  ('Minecraft for XOne', 'XOne', 'Microsoft Studios', 'Mojang', Decimal('5.43'), 2014),
#  ('Monster Hunter 4 Ultimate for 3DS', '3DS', 'Capcom', 'Capcom', Decimal('4.20'), 2015),
#  ('Monster Hunter 4 for 3DS', '3DS', 'Capcom', 'Capcom', Decimal('4.10'), 2013),
#  ('Monster Hunter Freedom 3 for PSP', 'PSP', 'Capcom', 'Capcom', Decimal('4.90'), 2010),
#  ('Monster Hunter Generations for 3DS', '3DS', 'Capcom', 'Capcom', Decimal('4.30'), 2016),
#  ('Monster Hunter: World for PS4', 'PS4', 'Capcom', 'Capcom', Decimal('4.00'), 2018),
#  ('Mortal Kombat 11 for PS4', 'PS4', 'NetherRealm Studios', 'Warner Bros. Interactive Entertainment', Decimal('4.20'), 2019),
#  ('Myst for PC', 'PC', 'Broderbund', 'Cyan Worlds', Decimal('6.30'), 1995),
#  ('NBA 2K20 for PS4', 'PS4', '2K Sports', 'Visual Concepts', Decimal('8.00'), 2019),
#  ('Namco Museum Vol.3 for PS', 'PS', 'Namco', 'Namco', Decimal('4.05'), 1997),
#  ('Namco Museum for GBA', 'GBA', 'Namco', 'Mass Media', Decimal('4.24'), 2001),
#  ('Namco Museum: 50th Anniversary for PS2', 'PS2', 'Namco', 'Digital Eclipse', Decimal('3.98'), 2005),
#  ('Need for Speed Underground 2 for PS2', 'PS2', 'Electronic Arts', 'EA Black Box', Decimal('6.90'), 2004),
#  ('Need for Speed Underground for PS2', 'PS2', 'Electronic Arts', 'EA Black Box', Decimal('7.20'), 2003),
#  ('Need for Speed: Most Wanted for PS2', 'PS2', 'Electronic Arts', 'EA Canada', Decimal('4.37'), 2005),
#  ('New Super Mario Bros. 2 for 3DS', '3DS', 'Nintendo', 'Nintendo', Decimal('13.34'), 2012),
#  ('New Super Mario Bros. U Deluxe for NS', 'NS', 'Nintendo', 'Nintendo EPD', Decimal('6.60'), 2019),
#  ('New Super Mario Bros. U for WiiU', 'WiiU', 'Nintendo', 'Nintendo EAD', Decimal('5.80'), 2012),
#  ('New Super Mario Bros. Wii for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('30.30'), 2009),
#  ('New Super Mario Bros. for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('30.80'), 2006),
#  ('Nintendo Land for WiiU', 'WiiU', 'Nintendo', 'Nintendo', Decimal('5.20'), 2012),
#  ('Nintendogs + cats for 3DS', '3DS', 'Nintendo', 'Nintendo EAD', Decimal('4.59'), 2011),
#  ('Nintendogs for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('23.96'), 2005),
#  ('Overwatch for PS4', 'PS4', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('4.54'), 2016),
#  ("PLAYERUNKNOWN'S BATTLEGROUNDS for PC", 'PC', 'PUBG Corporation', 'PUBG Corporation', Decimal('36.60'), 2017),
#  ('Pac-Man for 2600', '2600', 'Atari', 'Atari', Decimal('7.70'), 1982),
#  ('Pitfall! for 2600', '2600', 'Activision', 'Activision', Decimal('4.50'), 1982),
#  ('Pokemon Black / White Version for DS', 'DS', 'Nintendo', 'Game Freak', Decimal('15.64'), 2011),
#  ('Pokemon Black 2 and White 2 for DS', 'DS', 'Nintendo', 'Game Freak', Decimal('8.52'), 2012),
#  ('Pokemon Crystal Version for GBC', 'GBC', 'Nintendo', 'Game Freak', Decimal('6.39'), 2001),
#  ('Pokemon Diamond / Pearl Version for DS', 'DS', 'Nintendo', 'Game Freak', Decimal('17.67'), 2007),
#  ('Pokemon Emerald Version for GBA', 'GBA', 'Nintendo', 'Game Freak', Decimal('7.06'), 2005),
#  ('Pokemon FireRed / LeafGreen Version for GBA', 'GBA', 'Nintendo', 'Game Freak', Decimal('12.00'), 2004),
#  ('Pokemon Gold / Silver Version for GB', 'GB', 'Nintendo', 'Game Freak', Decimal('23.10'), 2000),
#  ('Pokemon Heart Gold / Soul Silver Version for DS', 'DS', 'Nintendo', 'Game Freak', Decimal('12.72'), 2010),
#  ('Pokemon Mystery Dungeon: Explorers of Time / Darkness for DS', 'DS', 'Nintendo', 'ChunSoft', Decimal('4.88'), 2008),
#  ('Pokemon Omega Ruby/Pokemon Alpha Sapphire for 3DS', '3DS', 'Nintendo', 'Game Freak', Decimal('14.27'), 2014),
#  ('Pokemon Pinball for GBC', 'GBC', 'Nintendo', 'Jupiter Corporation', Decimal('5.31'), 1999),
#  ('Pokemon Platinum Version for DS', 'DS', 'Nintendo', 'Game Freak', Decimal('7.60'), 2009),
#  ('Pokemon Red / Green / Blue Version for GB', 'GB', 'Nintendo', 'Game Freak', Decimal('31.38'), 1998),
#  ('Pokemon Ruby / Sapphire Version for GBA', 'GBA', 'Nintendo', 'Game Freak', Decimal('16.22'), 2003),
#  ('Pokemon Stadium for N64', 'N64', 'Nintendo', 'HAL Laboratory', Decimal('5.46'), 2000),
#  ('Pokemon Sun/Moon for 3DS', '3DS', 'Nintendo', 'Game Freak', Decimal('16.18'), 2016),
#  ('Pokemon Sword / Shield for NS', 'NS', 'Nintendo', 'Game Freak', Decimal('17.37'), 2019),
#  ('Pokemon X/Y for 3DS', '3DS', 'Nintendo', 'Game Freak', Decimal('16.45'), 2013),
#  ('Pokemon Yellow: Special Pikachu Edition for GB', 'GB', 'Nintendo', 'Game Freak', Decimal('14.64'), 1999),
#  ("Pokemon: Let's Go, Pikachu! for NS", 'NS', 'Nintendo', 'Game Freak', Decimal('4.57'), 2018),
#  ("Pokemon: Let's Go, Pikachu/Eevee for NS", 'NS', 'Nintendo', 'Game Freak', Decimal('11.97'), 2018),
#  ('Pokemon: Ultra Sun and Ultra Moon for 3DS', '3DS', 'Nintendo', 'Game Freak', Decimal('8.77'), 2017),
#  ('Portal 2 for PC', 'PC', 'Valve', 'Valve Software', Decimal('13.06'), 2011),
#  ('Portal for PC', 'PC', 'Valve Corporation', 'Valve Software', Decimal('9.97'), 2008),
#  ('Professor Layton and the Curious Village for DS', 'DS', 'Nintendo', 'Level 5', Decimal('4.49'), 2008),
#  ('Red Dead Redemption 2 for PS4', 'PS4', 'Rockstar Games', 'Rockstar Games', Decimal('13.94'), 2018),
#  ('Red Dead Redemption 2 for XOne', 'XOne', 'Rockstar Games', 'Rockstar Games', Decimal('5.77'), 2018),
#  ('Red Dead Redemption for PS3', 'PS3', 'Rockstar Games', 'Rockstar San Diego', Decimal('6.57'), 2011),
#  ('Red Dead Redemption for X360', 'X360', 'Rockstar Games', 'Rockstar San Diego', Decimal('6.50'), 2010),
#  ('Resident Evil 2 for PS', 'PS', 'Capcom', 'Capcom', Decimal('4.96'), 1998),
#  ('Resident Evil 5 for PS3', 'PS3', 'Capcom', 'Capcom', Decimal('5.10'), 2009),
#  ('Resistance: Fall of Man for PS3', 'PS3', 'Sony Computer Entertainment', 'Insomniac Games', Decimal('4.37'), 2006),
#  ('Riven: The Sequel to Myst for PC', 'PC', 'Red Orb', 'Cyan Worlds', Decimal('4.50'), 1997),
#  ('RollerCoaster Tycoon 3 for PC', 'PC', 'Atari', 'Frontier Developments', Decimal('10.00'), 2004),
#  ('Rust for PC', 'PC', 'Facepunch Studios', 'Facepunch Studios', Decimal('9.02'), 2018),
#  ("Sid Meier's Civilization VI for PC", 'PC', '2K Games', 'Firaxis Games', Decimal('5.50'), 2016),
#  ('Sonic the Hedgehog 2 for GEN', 'GEN', 'Sega', 'Sonic Team', Decimal('6.00'), 1992),
#  ('Sonic the Hedgehog for GEN', 'GEN', 'Sega', 'Sonic Team', Decimal('15.00'), 1991),
#  ('Spider-Man: The Movie for PS2', 'PS2', 'Activision', 'Treyarch', Decimal('4.48'), 2002),
#  ('Splatoon 2 for NS', 'NS', 'Nintendo', 'Nintendo EPD', Decimal('10.13'), 2017),
#  ('Splatoon for WiiU', 'WiiU', 'Nintendo', 'Nintendo EAD', Decimal('4.95'), 2015),
#  ('Spyro the Dragon for PS', 'PS', 'Sony Computer Entertainment', 'Insomniac Games', Decimal('5.00'), 1998),
#  ('Star Fox 64 for N64', 'N64', 'Nintendo', 'Nintendo EAD', Decimal('4.00'), 1997),
#  ('Star Wars Battlefront (2015) for PS4', 'PS4', 'Electronic Arts', 'EA DICE', Decimal('8.03'), 2015),
#  ('Star Wars Battlefront (2015) for XOne', 'XOne', 'Electronic Arts', 'EA DICE', Decimal('4.15'), 2015),
#  ('Star Wars Battlefront II (2017) for PS4', 'PS4', 'Electronic Arts', 'EA DICE', Decimal('4.53'), 2017),
#  ('StarCraft II: Wings of Liberty for PC', 'PC', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('4.50'), 2010),
#  ('StarCraft for PC', 'PC', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('11.00'), 1998),
#  ('Starbound for PC', 'PC', 'Infocom, Inc.', 'Unknown', Decimal('4.31'), 2014),
#  ('Stardew Valley for PC', 'PC', 'Chucklefish', 'ConcernedApe', Decimal('4.91'), 2016),
#  ('Street Fighter II Turbo for SNES', 'SNES', 'Capcom', 'Capcom', Decimal('4.10'), 1993),
#  ('Street Fighter II: The World Warrior for SNES', 'SNES', 'Capcom', 'Capcom', Decimal('6.30'), 1992),
#  ('Street Fighter IV for PS3', 'PS3', 'Capcom', 'Capcom / Dimps Corporation', Decimal('4.19'), 2009),
#  ('Super Mario 3D Land for 3DS', '3DS', 'Nintendo', 'Nintendo EAD Tokyo', Decimal('12.70'), 2011),
#  ('Super Mario 3D World for WiiU', 'WiiU', 'Nintendo', 'Nintendo EAD Tokyo', Decimal('5.84'), 2013),
#  ('Super Mario 64 DS for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('11.06'), 2004),
#  ('Super Mario 64 for N64', 'N64', 'Nintendo', 'Nintendo EAD', Decimal('11.91'), 1996),
#  ('Super Mario Advance 4: Super Mario Bros. 3 for GBA', 'GBA', 'Nintendo', 'Nintendo EAD', Decimal('5.43'), 2003),
#  ('Super Mario Advance for GBA', 'GBA', 'Nintendo', 'Nintendo EAD', Decimal('5.57'), 2001),
#  ('Super Mario All-Stars for SNES', 'SNES', 'Nintendo', 'Nintendo EAD', Decimal('10.55'), 1993),
#  ('Super Mario Bros. 2 for NES', 'NES', 'Nintendo', 'Nintendo EAD', Decimal('7.46'), 1988),
#  ('Super Mario Bros. 3 for NES', 'NES', 'Nintendo', 'Nintendo R&D2', Decimal('17.28'), 1990),
#  ('Super Mario Bros. Deluxe for GB', 'GB', 'Nintendo', 'Nintendo EAD', Decimal('5.07'), 1999),
#  ('Super Mario Bros. for NES', 'NES', 'Nintendo', 'Nintendo EAD', Decimal('40.24'), 1985),
#  ('Super Mario Galaxy 2 for Wii', 'Wii', 'Nintendo', 'Nintendo EAD Tokyo', Decimal('7.41'), 2010),
#  ('Super Mario Galaxy for Wii', 'Wii', 'Nintendo', 'Nintendo EAD Tokyo', Decimal('12.80'), 2007),
#  ('Super Mario Kart for SNES', 'SNES', 'Nintendo', 'Nintendo EAD', Decimal('8.76'), 1992),
#  ('Super Mario Land 2: 6 Golden Coins for GB', 'GB', 'Nintendo', 'Nintendo R&D1', Decimal('11.18'), 1992),
#  ('Super Mario Land 3: Wario Land for GB', 'GB', 'Nintendo', 'Nintendo R&D1', Decimal('5.19'), 1994),
#  ('Super Mario Land for GB', 'GB', 'Nintendo', 'Nintendo R&D1', Decimal('18.14'), 1989),
#  ('Super Mario Maker 2 for NS', 'NS', 'Nintendo', 'Nintendo', Decimal('5.48'), 2019),
#  ('Super Mario Maker for WiiU', 'WiiU', 'Nintendo', 'Nintendo EAD', Decimal('4.01'), 2015),
#  ('Super Mario Odyssey for NS', 'NS', 'Nintendo', 'Nintendo EPD', Decimal('17.41'), 2017),
#  ('Super Mario Party for NS', 'NS', 'Nintendo', 'Nd Cube Co., Ltd.', Decimal('10.10'), 2018),
#  ('Super Mario Sunshine for GC', 'GC', 'Nintendo', 'Nintendo EAD', Decimal('5.91'), 2002),
#  ("Super Mario World 2: Yoshi's Island for SNES", 'SNES', 'Nintendo', 'Nintendo EAD', Decimal('4.12'), 1995),
#  ('Super Mario World for SNES', 'SNES', 'Nintendo', 'Nintendo EAD', Decimal('20.61'), 1991),
#  ('Super Mario World: Super Mario Advance 2 for GBA', 'GBA', 'Nintendo', 'Nintendo EAD', Decimal('5.69'), 2002),
#  ('Super Paper Mario for Wii', 'Wii', 'Nintendo', 'Intelligent Systems', Decimal('4.23'), 2007),
#  ('Super Smash Bros. Brawl for Wii', 'Wii', 'Nintendo', 'Project Sora', Decimal('13.32'), 2008),
#  ('Super Smash Bros. Melee for GC', 'GC', 'Nintendo', 'HAL Laboratory', Decimal('7.41'), 2001),
#  ('Super Smash Bros. Ultimate for NS', 'NS', 'Nintendo', 'Bandai Namco Games', Decimal('18.84'), 2018),
#  ('Super Smash Bros. for 3DS for 3DS', '3DS', 'Nintendo', 'Bandai Namco Games', Decimal('9.59'), 2014),
#  ('Super Smash Bros. for N64', 'N64', 'Nintendo', 'HAL Laboratory', Decimal('5.55'), 1999),
#  ('Super Smash Bros. for Wii U for WiiU', 'WiiU', 'Nintendo', 'Bandai Namco Games', Decimal('5.37'), 2014),
#  ('Teenage Mutant Ninja Turtles for NES', 'NES', 'Ultra Games', 'Konami', Decimal('4.17'), 1989),
#  ('Tekken 2 for PS', 'PS', 'Namco', 'Namco', Decimal('5.74'), 1996),
#  ('Tekken 3 for PS', 'PS', 'Namco', 'Namco', Decimal('8.30'), 1998),
#  ('Tekken Tag Tournament for PS2', 'PS2', 'Namco', 'Namco', Decimal('4.05'), 2000),
#  ('Terraria for PC', 'PC', 'Unknown', 'Re-Logic', Decimal('14.00'), 2011),
#  ('Tetris for GB', 'GB', 'Nintendo', 'Bullet Proof Software', Decimal('30.26'), 1989),
#  ('Tetris for NES', 'NES', 'Nintendo', 'Nintendo', Decimal('5.58'), 1989),
#  ('The Binding of Isaac for PC', 'PC', 'Edmund McMillen', 'Edmund McMillen', Decimal('7.17'), 2011),
#  ('The Elder Scrolls IV: Oblivion for X360', 'X360', 'Take-Two Interactive', 'Bethesda Softworks', Decimal('4.47'), 2009),
#  ('The Elder Scrolls V: Skyrim for PC', 'PC', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('3.99'), 2011),
#  ('The Elder Scrolls V: Skyrim for PS3', 'PS3', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('6.49'), 2011),
#  ('The Elder Scrolls V: Skyrim for X360', 'X360', 'Bethesda Softworks', 'Bethesda Game Studios', Decimal('8.88'), 2011),
#  ('The Forest for PC', 'PC', 'Endnight Games Ltd', 'Unknown', Decimal('5.30'), 2014),
#  ('The Last of Us Remastered for PS4', 'PS4', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('11.78'), 2014),
#  ('The Last of Us for PS3', 'PS3', 'Sony Computer Entertainment America', 'Naughty Dog', Decimal('8.15'), 2013),
#  ('The Last of Us: Part II for PS4', 'PS4', 'Sony Interactive Entertainment', 'Naughty Dog', Decimal('4.00'), 2020),
#  ('The Legend of Zelda for NES', 'NES', 'Nintendo', 'Nintendo EAD', Decimal('6.51'), 1987),
#  ('The Legend of Zelda: A Link Between Worlds for 3DS', '3DS', 'Nintendo', 'Nintendo EAD', Decimal('4.07'), 2013),
#  ('The Legend of Zelda: A Link to the Past for SNES', 'SNES', 'Nintendo', 'Nintendo EAD', Decimal('4.61'), 1992),
#  ('The Legend of Zelda: Breath of the Wild for NS', 'NS', 'Nintendo', 'Nintendo EPD', Decimal('17.41'), 2017),
#  ("The Legend of Zelda: Link's Awakening for NS", 'NS', 'Nintendo', 'Nintendo', Decimal('4.38'), 2019),
#  ('The Legend of Zelda: Ocarina of Time 3D for 3DS', '3DS', 'Nintendo', 'GREZZO', Decimal('6.02'), 2011),
#  ('The Legend of Zelda: Ocarina of Time for N64', 'N64', 'Nintendo', 'Nintendo EAD', Decimal('7.60'), 1998),
#  ('The Legend of Zelda: Oracle of Ages / Seasons for GBC', 'GBC', 'Nintendo', 'Capcom', Decimal('3.99'), 2001),
#  ('The Legend of Zelda: Phantom Hourglass for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('4.76'), 2007),
#  ('The Legend of Zelda: The Wind Waker for GC', 'GC', 'Nintendo', 'Nintendo EAD', Decimal('4.43'), 2003),
#  ('The Legend of Zelda: Twilight Princess for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('7.26'), 2006),
#  ('The Lord of the Rings: The Two Towers for PS2', 'PS2', 'Electronic Arts', 'Stormfront Studios', Decimal('4.67'), 2002),
#  ('The Simpsons: Hit & Run for PS2', 'PS2', 'VU Games', 'Radical Entertainment', Decimal('4.70'), 2003),
#  ('The Sims 3 for PC', 'PC', 'Electronic Arts', 'EA Redwood Shores', Decimal('7.96'), 2009),
#  ('The Sims 4 for PC', 'PC', 'Electronic Arts', 'Maxis', Decimal('4.10'), 2014),
#  ('The Witcher 3: Wild Hunt for PC', 'PC', 'Warner Bros. Interactive Entertainment', 'CD Projekt Red Studio', Decimal('12.40'), 2015),
#  ('The Witcher 3: Wild Hunt for PS4', 'PS4', 'Warner Bros. Interactive Entertainment', 'CD Projekt Red Studio', Decimal('10.80'), 2015),
#  ('The Witcher 3: Wild Hunt for XOne', 'XOne', 'Warner Bros. Interactive Entertainment', 'CD Projekt Red Studio', Decimal('4.30'), 2015),
#  ("Tom Clancy's Rainbow Six: Siege for PS4", 'PS4', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.36'), 2015),
#  ("Tom Clancy's The Division for PS4", 'PS4', 'Ubisoft', 'Massive Entertainment', Decimal('4.37'), 2016),
#  ('Tomb Raider (2013) for PC', 'PC', 'Square Enix', 'Crystal Dynamics', Decimal('5.50'), 2013),
#  ('Tomb Raider II for PS', 'PS', 'Eidos Interactive', 'Core Design Ltd.', Decimal('5.24'), 1997),
#  ('Tomb Raider for PS', 'PS', 'Eidos Interactive', 'Core Design Ltd.', Decimal('4.63'), 1996),
#  ('Tomodachi Life for 3DS', '3DS', 'Nintendo', 'Nintendo', Decimal('6.59'), 2014),
#  ("Tony Hawk's Pro Skater 2 for PS", 'PS', 'Activision', 'Neversoft Entertainment', Decimal('4.68'), 2000),
#  ("Tony Hawk's Pro Skater 3 for PS2", 'PS2', 'Activision', 'Neversoft Entertainment', Decimal('4.41'), 2001),
#  ("Tony Hawk's Pro Skater for PS", 'PS', 'Activision', 'Neversoft Entertainment', Decimal('5.02'), 1999),
#  ('Uncharted 2: Among Thieves for PS3', 'PS3', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('6.74'), 2009),
#  ("Uncharted 3: Drake's Deception for PS3", 'PS3', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('9.30'), 2011),
#  ("Uncharted 4: A Thief's End for PS4", 'PS4', 'Sony Interactive Entertainment', 'Naughty Dog', Decimal('16.25'), 2016),
#  ("Uncharted: Drake's Fortune for PS3", 'PS3', 'Sony Computer Entertainment', 'Naughty Dog', Decimal('4.97'), 2007),
#  ('Uncharted: The Nathan Drake Collection for PS4', 'PS4', 'Sony Computer Entertainment', 'Bluepoint Games', Decimal('5.70'), 2015),
#  ('Warcraft III: Reign of Chaos for PC', 'PC', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('4.50'), 2002),
#  ('Warzone 2100 for PS', 'PS', 'Eidos Interactive', 'Pumpkin Studios', Decimal('5.01'), 1999),
#  ('Watch Dogs for PS4', 'PS4', 'Ubisoft', 'Ubisoft Montreal', Decimal('4.32'), 2014),
#  ('Wii Fit Plus for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('21.13'), 2009),
#  ('Wii Fit for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('22.67'), 2008),
#  ('Wii Party for Wii', 'Wii', 'Nintendo', 'Nd Cube Co., Ltd.', Decimal('9.34'), 2010),
#  ('Wii Play for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('28.02'), 2007),
#  ('Wii Sports Resort for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('33.13'), 2009),
#  ('Wii Sports for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('82.90'), 2006),
#  ('Winning Eleven: Pro Evolution Soccer 2007 for PS2', 'PS2', 'Konami', 'Konami Computer Entertainment Tokyo', Decimal('4.39'), 2007),
#  ('World Soccer Winning Eleven 9 for PS2', 'PS2', 'Konami', 'Konami Computer Entertainment Tokyo', Decimal('4.06'), 2006),
#  ('World of Warcraft for PC', 'PC', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('12.00'), 2004),
#  ('World of Warcraft: Cataclysm for PC', 'PC', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('4.70'), 2010),
#  ('World of Warcraft: Wrath of the Lich King for PC', 'PC', 'Blizzard Entertainment', 'Blizzard Entertainment', Decimal('4.00'), 2008),
#  ('Yokai Watch 2: Bony Spirits / Fleshy Souls / Psychic Specters for 3DS', '3DS', 'Nintendo', 'Level 5', Decimal('7.29'), 2016),
#  ('Zelda II: The Adventure of Link for NES', 'NES', 'Nintendo', 'Nintendo EAD', Decimal('4.38'), 1988)]

# %%
# %%sql
# postgresql:///games
#
# -- Select all information for the top ten best-selling games
# -- Order the results from best-selling game down to tenth best-selling
#
# select *
# from game_sales
# order by games_sold desc
# limit 10
# Out:
# 10 rows affected.
# [('Wii Sports for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('82.90'), 2006),
#  ('Super Mario Bros. for NES', 'NES', 'Nintendo', 'Nintendo EAD', Decimal('40.24'), 1985),
#  ('Counter-Strike: Global Offensive for PC', 'PC', 'Valve', 'Valve Corporation', Decimal('40.00'), 2012),
#  ('Mario Kart Wii for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('37.32'), 2008),
#  ("PLAYERUNKNOWN'S BATTLEGROUNDS for PC", 'PC', 'PUBG Corporation', 'PUBG Corporation', Decimal('36.60'), 2017),
#  ('Minecraft for PC', 'PC', 'Mojang', 'Mojang AB', Decimal('33.15'), 2010),
#  ('Wii Sports Resort for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('33.13'), 2009),
#  ('Pokemon Red / Green / Blue Version for GB', 'GB', 'Nintendo', 'Game Freak', Decimal('31.38'), 1998),
#  ('New Super Mario Bros. for DS', 'DS', 'Nintendo', 'Nintendo EAD', Decimal('30.80'), 2006),
#  ('New Super Mario Bros. Wii for Wii', 'Wii', 'Nintendo', 'Nintendo EAD', Decimal('30.30'), 2009)]

# %% [markdown]
# ## 2. Missing review scores
# <p>Wow, the best-selling video games were released between 1985 to 2017! That's quite a range; we'll have to use data from the <code>reviews</code> table to gain more insight on the best years for video games. </p>
# <p>First, it's important to explore the limitations of our database. One big shortcoming is that there is not any <code>reviews</code> data for some of the games on the <code>game_sales</code> table. </p>

# %%
# %%sql
#
# -- Join games_sales and reviews
# -- Select a count of the number of games where both critic_score and user_score are null
# Select count(*)
# from game_sales gs
# left join reviews r
# on gs.game = r.game
# where r.critic_score is null and
# r.user_score is null
# Out:
#  * postgresql:///games
# 1 rows affected.
# [(31,)]

# %% [markdown]
# ## 3. Years that video game critics loved
# <p>It looks like a little less than ten percent of the games on the <code>game_sales</code> table don't have any reviews data. That's a small enough percentage that we can continue our exploration, but the missing reviews data is a good thing to keep in mind as we move on to evaluating results from more sophisticated queries. </p>
# <p>There are lots of ways to measure the best years for video games! Let's start with what the critics think. </p>

# %%
# %%sql
#
# -- Select release year and average critic score for each year, rounded and aliased
# -- Join the game_sales and reviews tables
# -- Group by release year
# -- Order the data from highest to lowest avg_critic_score and limit to 10 results
#
# select g.year, round(avg(r.critic_score),2) as avg_critic_score
# from game_sales g
# Inner Join reviews r
# on g.game = r.game
# group by g.year
# order by avg_critic_score desc
# limit 10
# Out:
#  * postgresql:///games
# 10 rows affected.
# [(1990, Decimal('9.80')),
#  (1992, Decimal('9.67')),
#  (1998, Decimal('9.32')),
#  (2020, Decimal('9.20')),
#  (1993, Decimal('9.10')),
#  (1995, Decimal('9.07')),
#  (2004, Decimal('9.03')),
#  (1982, Decimal('9.00')),
#  (2002, Decimal('8.99')),
#  (1999, Decimal('8.93'))]

# %% [markdown]
# ## 4. Was 1982 really that great?
# <p>The range of great years according to critic reviews goes from 1982 until 2020: we are no closer to finding the golden age of video games! </p>
# <p>Hang on, though. Some of those <code>avg_critic_score</code> values look like suspiciously round numbers for averages. The value for 1982 looks especially fishy. Maybe there weren't a lot of video games in our dataset that were released in certain years. </p>
# <p>Let's update our query and find out whether 1982 really was such a great year for video games.</p>

# %%
# %%sql
#
# -- Paste your query from the previous task; update it to add a count of games released in each year called num_games
# -- Update the query so that it only returns years that have more than four reviewed games
#
# select g.year, round(avg(r.critic_score),2) as avg_critic_score,
# count(g.game) as num_games
# from game_sales g
# Inner Join reviews r
# on g.game = r.game
# group by g.year
# Having count(g.game) > 4
# order by avg_critic_score desc
# limit 10
# Out:
#  * postgresql:///games
# 10 rows affected.
# [(1998, Decimal('9.32'), 10),
#  (2004, Decimal('9.03'), 11),
#  (2002, Decimal('8.99'), 9),
#  (1999, Decimal('8.93'), 11),
#  (2001, Decimal('8.82'), 13),
#  (2011, Decimal('8.76'), 26),
#  (2016, Decimal('8.67'), 13),
#  (2013, Decimal('8.66'), 18),
#  (2008, Decimal('8.63'), 20),
#  (2017, Decimal('8.62'), 13)]

# %% [markdown]
# ## 5. Years that dropped off the critics' favorites list
# <p>That looks better! The <code>num_games</code> column convinces us that our new list of the critics' top games reflects years that had quite a few well-reviewed games rather than just one or two hits. But which years dropped off the list due to having four or fewer reviewed games? Let's identify them so that someday we can track down more game reviews for those years and determine whether they might rightfully be considered as excellent years for video game releases!</p>
# <p>It's time to brush off your set theory skills. To get started, we've created tables with the results of our previous two queries:</p>
# <h3 id="top_critic_years"><code>top_critic_years</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>year</code></td>
# <td>int</td>
# <td>Year of video game release</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>avg_critic_score</code></td>
# <td>float</td>
# <td>Average of all critic scores for games released in that year</td>
# </tr>
# </tbody>
# </table>
# <h3 id="top_critic_years_more_than_four_games"><code>top_critic_years_more_than_four_games</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>year</code></td>
# <td>int</td>
# <td>Year of video game release</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>num_games</code></td>
# <td>int</td>
# <td>Count of the number of video games released in that year</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>avg_critic_score</code></td>
# <td>float</td>
# <td>Average of all critic scores for games released in that year</td>
# </tr>
# </tbody>
# </table>

# %%
# %%sql
#
# -- Select the year and avg_critic_score for those years that dropped off the list of critic favorites
# -- Order the results from highest to lowest avg_critic_score
#
# SELECT year, avg_critic_score
# FROM top_critic_years
# EXCEPT
# SELECT year, avg_critic_score
# FROM top_critic_years_more_than_four_games
# ORDER BY avg_critic_score DESC;
# Out:
#  * postgresql:///games
# 6 rows affected.
# [(1990, Decimal('9.80')),
#  (1992, Decimal('9.67')),
#  (2020, Decimal('9.20')),
#  (1993, Decimal('9.10')),
#  (1995, Decimal('9.07')),
#  (1982, Decimal('9.00'))]

# %% [markdown]
# ## 6. Years video game players loved
# <p>Based on our work in the task above, it looks like the early 1990s might merit consideration as the golden age of video games based on <code>critic_score</code> alone, but we'd need to gather more games and reviews data to do further analysis. </p>
# <p>Let's move on to looking at the opinions of another important group of people: players! To begin, let's create a query very similar to the one we used in Task Four, except this one will look at <code>user_score</code> averages by year rather than <code>critic_score</code> averages.</p>

# %%
# %%sql
#
# -- Select year, an average of user_score, and a count of games released in a given year, aliased and rounded
# -- Include only years with more than four reviewed games; group data by year
# -- Order data by avg_user_score, and limit to ten results
#
# select g.year, round(avg(r.user_score),2) as avg_user_score,
# count(g.game) as num_games
# from game_sales g
# Inner Join reviews r
# on g.game = r.game
# group by g.year
# Having count(g.game) > 4
# order by avg_user_score desc
# limit 10
# Out:
#  * postgresql:///games
# 10 rows affected.
# [(1997, Decimal('9.50'), 8),
#  (1998, Decimal('9.40'), 10),
#  (2010, Decimal('9.24'), 23),
#  (2009, Decimal('9.18'), 20),
#  (2008, Decimal('9.03'), 20),
#  (1996, Decimal('9.00'), 5),
#  (2005, Decimal('8.95'), 13),
#  (2006, Decimal('8.95'), 16),
#  (2000, Decimal('8.80'), 8),
#  (2002, Decimal('8.80'), 9)]

# %% [markdown]
# ## 7. Years that both players and critics loved
# <p>Alright, we've got a list of the top ten years according to both critic reviews and user reviews. Are there any years that showed up on both tables? If so, those years would certainly be excellent ones!</p>
# <p>Recall that we have access to the <code>top_critic_years_more_than_four_games</code> table, which stores the results of our top critic years query from Task 4:</p>
# <h3 id="top_critic_years_more_than_four_games"><code>top_critic_years_more_than_four_games</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>year</code></td>
# <td>int</td>
# <td>Year of video game release</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>num_games</code></td>
# <td>int</td>
# <td>Count of the number of video games released in that year</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>avg_critic_score</code></td>
# <td>float</td>
# <td>Average of all critic scores for games released in that year</td>
# </tr>
# </tbody>
# </table>
# <p>We've also saved the results of our top user years query from the previous task into a table:</p>
# <h3 id="top_user_years_more_than_four_games"><code>top_user_years_more_than_four_games</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>year</code></td>
# <td>int</td>
# <td>Year of video game release</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>num_games</code></td>
# <td>int</td>
# <td>Count of the number of video games released in that year</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>avg_user_score</code></td>
# <td>float</td>
# <td>Average of all user scores for games released in that year</td>
# </tr>
# </tbody>
# </table>

# %%
# %%sql
#
# -- Select the year results that appear on both tables
#
# Select year
# from top_critic_years_more_than_four_games
# Intersect
# Select year
# from top_user_years_more_than_four_games
# Out:
#  * postgresql:///games
# 3 rows affected.
# [(1998,), (2008,), (2002,)]

# %% [markdown]
# ## 8. Sales in the best video game years
# <p>Looks like we've got three years that both users and critics agreed were in the top ten! There are many other ways of measuring what the best years for video games are, but let's stick with these years for now. We know that critics and players liked these years, but what about video game makers? Were sales good? Let's find out.</p>
# <p>This time, we haven't saved the results from the previous task in a table for you. Instead, we'll use the query from the previous task as a subquery in this one! This is a great skill to have, as we don't always have write permissions on the database we are querying.</p>

# %%
# %%sql
#
# -- Select year and sum of games_sold, aliased as total_games_sold; order results by total_games_sold descending
# -- Filter game_sales based on whether each year is in the list returned in the previous task
#
# select year, sum(games_sold) as total_games_sold
# from game_sales
# where year in (Select year
# from top_critic_years_more_than_four_games
# Intersect
# Select year
# from top_user_years_more_than_four_games)
# group by year
# order by total_games_sold desc;
# Out:
#  * postgresql:///games
# 3 rows affected.
# [(2008, Decimal('175.07')),
#  (1998, Decimal('101.52')),
#  (2002, Decimal('58.67'))]
